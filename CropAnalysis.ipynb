# %% [markdown]
# <a href="https://colab.research.google.com/github/SageChisanga/Data-Science/blob/main/CropAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📌 AUTHOR: Chisanga Kabwe
# Analysis of Cowpea Mutants under Drought & Low Phosphorus
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
# @title Cleaning and Descriptive stats
# ----------------------------
# 1. Load Dataset
# ----------------------------
df = pd.read_excel("/content/data.gh.csv")  # Make sure this is the correct path

# ----------------------------
# 2. Clean & Preview Data
# ----------------------------
# Standardize column names
df.columns = [col.strip().upper() for col in df.columns]
df = df.rename(columns={
    'GNTP': 'GENOTYPE',
    'PLEV': 'P',
    'MLEV': 'M'
})
df = df.dropna()
print("\nColumns after cleaning:", df.columns.tolist())

# ----------------------------
# 3. Descriptive Stats
# ----------------------------
print("\nSummary Statistics:\n", df.describe())
# Out:
# Columns after cleaning: ['GENOTYPE', 'M', 'P', 'REP', 'NTRL', 'NOBR', 'PLHT', 'STMD', 'RTD', 'PTBM', 'RTBM', 'PLDY', 'GRNY', 'RTL', 'TBM', 'PTBMP', 'RTBMP', 'PLDYP', 'GRNYP']
#
# Summary Statistics:
#                  M           P         REP        NTRL        NOBR        PLHT  \
# count  123.000000  123.000000  123.000000  123.000000  123.000000  123.000000
# mean    67.317073   50.804878    1.983740    5.268293    4.560976   80.211382
# std     24.994202   28.608052    0.819673    1.403001    1.594799   33.413272
# min     40.000000   23.000000    1.000000    2.000000    1.000000   23.000000
# 25%     40.000000   23.000000    1.000000    4.000000    4.000000   48.000000
# 50%     60.000000   23.000000    2.000000    5.000000    5.000000   84.000000
# 75%    100.000000   80.000000    3.000000    6.000000    6.000000  103.000000
# max    100.000000   80.000000    3.000000    9.000000    8.000000  159.000000
#
#              STMD         RTD        PTBM        RTBM        PLDY        GRNY  \
# count  123.000000  123.000000  123.000000  123.000000  123.000000  123.000000
# mean     2.551220    0.368699   57.382412    9.264977    9.541585   11.991138
# std      0.374684    0.114955   16.784156    4.624725    8.605920   13.534135
# min      1.700000    0.040000   23.870000    2.334000    0.000000    0.000000
# 25%      2.300000    0.305000   45.855000    4.959778    3.465000    4.210000
# 50%      2.500000    0.370000   53.710000    9.445000    6.770000    6.590000
# 75%      2.700000    0.470000   65.556667   12.368444   14.575000   13.685000
# max      3.700000    0.590000  107.883333   21.183000   39.590000   49.080000
#
#               RTL         TBM       PTBMP       RTBMP       PLDYP       GRNYP
# count  123.000000  123.000000  123.000000  123.000000  123.000000  123.000000
# mean    33.439634   88.180112   67.114590   11.173485    9.963569   11.748356
# std      9.401108   27.834375   13.444066    5.655500    6.713689    9.790815
# min     14.400000   34.919000   32.909068    1.588960    0.000000    0.000000
# 25%     26.150000   69.122500   58.369995    7.413824    4.608786    5.225940
# 50%     33.000000   81.373778   70.456627   10.728037    8.428717    8.825111
# 75%     39.800000  101.861875   77.576918   14.260030   14.691043   15.748825
# max     58.300000  161.665889   91.104699   27.644728   28.843702   37.740782

# %%
# @title ANOVA
from statsmodels.formula.api import ols
import statsmodels.api as sm

print("\n📌 One-Way ANOVA Across Genotypes with Group Means")

# Traits to analyze
available_traits = ['NOBR', 'PLHT', 'STMD', 'RTBM', 'RTD', 'RTL', 'GRNY', 'PLDY', 'PTBM', 'TBM']
available_traits = [trait for trait in available_traits if trait in df.columns]

print("\nTraits to analyze:", available_traits)

for trait in available_traits:
    try:
        print(f"\n📊 ANOVA for {trait} (by GENOTYPE):")

        # ANOVA
        model = ols(f'{trait} ~ C(GENOTYPE)', data=df).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)
        print(anova_table)

        # Means per genotype
        print(f"\n📌 Mean {trait} per Genotype:")
        print(df.groupby("GENOTYPE")[trait].mean().round(2).sort_values(ascending=False))

    except Exception as e:
        print(f"\n⚠️ Error analyzing {trait}: {str(e)}")
# Out:
# 📌 One-Way ANOVA Across Genotypes with Group Means
#
# Traits to analyze: ['NOBR', 'PLHT', 'STMD', 'RTBM', 'RTD', 'RTL', 'GRNY', 'PLDY', 'PTBM', 'TBM']
#
# 📊 ANOVA for NOBR (by GENOTYPE):
#                  sum_sq     df         F    PR(>F)
# C(GENOTYPE)   18.209350    6.0  1.205298  0.308545
# Residual     292.083333  116.0       NaN       NaN
#
# 📌 Mean NOBR per Genotype:
# GENOTYPE
# BB 8 -1 -5-2    5.00
# BB 3-9-7-5      4.94
# MS 1-8-1-4      4.89
# LT 11-3-3-12    4.67
# LT PRT          4.28
# MS PRT          4.12
# BB PRT          4.00
# Name: NOBR, dtype: float64
#
# 📊 ANOVA for PLHT (by GENOTYPE):
#                     sum_sq     df         F    PR(>F)
# C(GENOTYPE)    7994.886826    6.0  1.205568  0.308406
# Residual     128211.617239  116.0       NaN       NaN
#
# 📌 Mean PLHT per Genotype:
# GENOTYPE
# MS PRT          96.31
# LT PRT          84.11
# MS 1-8-1-4      82.50
# BB 8 -1 -5-2    81.53
# BB PRT          75.72
# LT 11-3-3-12    74.94
# BB 3-9-7-5      68.22
# Name: PLHT, dtype: float64
#
# 📊 ANOVA for STMD (by GENOTYPE):
#                 sum_sq     df         F    PR(>F)
# C(GENOTYPE)   0.419507    6.0  0.485429  0.818097
# Residual     16.707810  116.0       NaN       NaN
#
# 📌 Mean STMD per Genotype:
# GENOTYPE
# BB 3-9-7-5      2.61
# MS PRT          2.60
# BB PRT          2.59
# LT 11-3-3-12    2.58
# LT PRT          2.54
# BB 8 -1 -5-2    2.52
# MS 1-8-1-4      2.43
# Name: STMD, dtype: float64
#
# 📊 ANOVA for RTBM (by GENOTYPE):
#                   sum_sq     df        F    PR(>F)
# C(GENOTYPE)   722.093089    6.0  7.39724  0.000001
# Residual     1887.253320  116.0      NaN       NaN
#
# 📌 Mean RTBM per Genotype:
# GENOTYPE
# MS PRT          12.04
# LT 11-3-3-12    10.44
# BB 3-9-7-5      10.23
# LT PRT          10.00
# BB PRT           9.78
# BB 8 -1 -5-2     8.87
# MS 1-8-1-4       3.79
# Name: RTBM, dtype: float64
#
# 📊 ANOVA for RTD (by GENOTYPE):
#                sum_sq     df         F    PR(>F)
# C(GENOTYPE)  0.218820    6.0  3.036169  0.008551
# Residual     1.393372  116.0       NaN       NaN
#
# 📌 Mean RTD per Genotype:
# GENOTYPE
# LT 11-3-3-12    0.43
# MS PRT          0.40
# MS 1-8-1-4      0.38
# BB 8 -1 -5-2    0.37
# BB 3-9-7-5      0.36
# BB PRT          0.36
# LT PRT          0.29
# Name: RTD, dtype: float64
#
# 📊 ANOVA for RTL (by GENOTYPE):
#                   sum_sq     df          F        PR(>F)
# C(GENOTYPE)  5415.244201    6.0  19.506332  1.236434e-15
# Residual     5367.217127  116.0        NaN           NaN
#
# 📌 Mean RTL per Genotype:
# GENOTYPE
# BB PRT          43.38
# LT 11-3-3-12    39.34
# BB 8 -1 -5-2    37.10
# LT PRT          32.56
# MS 1-8-1-4      31.39
# BB 3-9-7-5      26.68
# MS PRT          22.63
# Name: RTL, dtype: float64
#
# 📊 ANOVA for GRNY (by GENOTYPE):
#                    sum_sq     df          F        PR(>F)
# C(GENOTYPE)  11133.044061    6.0  19.193698  1.945228e-15
# Residual     11214.037379  116.0        NaN           NaN
#
# 📌 Mean GRNY per Genotype:
# GENOTYPE
# MS PRT          31.11
# MS 1-8-1-4      22.90
# LT PRT           8.95
# LT 11-3-3-12     7.99
# BB 8 -1 -5-2     5.90
# BB PRT           4.75
# BB 3-9-7-5       4.13
# Name: GRNY, dtype: float64
#
# 📊 ANOVA for PLDY (by GENOTYPE):
#                   sum_sq     df          F        PR(>F)
# C(GENOTYPE)  5614.698205    6.0  31.732133  2.388316e-22
# Residual     3420.848861  116.0        NaN           NaN
#
# 📌 Mean PLDY per Genotype:
# GENOTYPE
# MS 1-8-1-4      23.53
# MS PRT          15.38
# LT PRT           7.69
# LT 11-3-3-12     6.86
# BB 3-9-7-5       5.78
# BB 8 -1 -5-2     4.24
# BB PRT           3.67
# Name: PLDY, dtype: float64
#
# 📊 ANOVA for PTBM (by GENOTYPE):
#                    sum_sq     df         F    PR(>F)
# C(GENOTYPE)   6174.921035    6.0  4.234382  0.000684
# Residual     28193.441568  116.0       NaN       NaN
#
# 📌 Mean PTBM per Genotype:
# GENOTYPE
# LT 11-3-3-12    69.94
# MS PRT          61.95
# BB 3-9-7-5      59.42
# MS 1-8-1-4      58.82
# BB PRT          54.36
# LT PRT          49.50
# BB 8 -1 -5-2    47.65
# Name: PTBM, dtype: float64
#
# 📊 ANOVA for TBM (by GENOTYPE):
#                    sum_sq     df          F        PR(>F)
# C(GENOTYPE)  41629.354423    6.0  15.217006  8.510900e-13
# Residual     52890.441762  116.0        NaN           NaN
#
# 📌 Mean TBM per Genotype:
# GENOTYPE
# MS PRT          120.48
# MS 1-8-1-4      109.04
# LT 11-3-3-12     95.22
# BB 3-9-7-5       79.55
# LT PRT           76.14
# BB PRT           72.56
# BB 8 -1 -5-2     66.66
# Name: TBM, dtype: float64

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

print("\n📌 Stratified ANOVA: Genotype Performance Within Each Treatment Level")

# Traits to analyze
available_traits = ['NOBR', 'PLHT', 'STMD', 'RTBM', 'RTD', 'RTL', 'GRNY', 'PLDY', 'PTBM', 'TBM']
available_traits = [trait for trait in available_traits if trait in df.columns]

# Treatment levels
phosphorus_levels = sorted(df['P'].unique())
moisture_levels = sorted(df['M'].unique())

# 🔁 Loop over each trait
for trait in available_traits:
    print(f"\n===========================\n📊 Trait: {trait}\n===========================")

    # --- ANOVA within each phosphorus level ---
    for p_level in phosphorus_levels:
        subset = df[df['P'] == p_level]
        print(f"\n🔍 ANOVA for {trait} at Phosphorus = {p_level}")
        try:
            model = ols(f'{trait} ~ C(GENOTYPE)', data=subset).fit()
            anova_table = sm.stats.anova_lm(model, typ=2)
            print(anova_table)

            print(f"\n📌 Mean {trait} per Genotype (P = {p_level}):")
            print(subset.groupby("GENOTYPE")[trait].mean().round(2).sort_values(ascending=False))
        except Exception as e:
            print(f"⚠️ Skipped P={p_level}: {e}")

    # --- ANOVA within each moisture level ---
    for m_level in moisture_levels:
        subset = df[df['M'] == m_level]
        print(f"\n💧 ANOVA for {trait} at Moisture = {m_level}")
        try:
            model = ols(f'{trait} ~ C(GENOTYPE)', data=subset).fit()
            anova_table = sm.stats.anova_lm(model, typ=2)
            print(anova_table)

            print(f"\n📌 Mean {trait} per Genotype (M = {m_level}):")
            print(subset.groupby("GENOTYPE")[trait].mean().round(2).sort_values(ascending=False))
        except Exception as e:
            print(f"⚠️ Skipped M={m_level}: {e}")
# Out:
# 📌 Stratified ANOVA: Genotype Performance Within Each Treatment Level
#
# ===========================
# 📊 Trait: NOBR
# ===========================
#
# 🔍 ANOVA for NOBR at Phosphorus = 23
#                  sum_sq    df         F   PR(>F)
# C(GENOTYPE)   23.512698   6.0  1.634854  0.15465
# Residual     134.233333  56.0       NaN      NaN
#
# 📌 Mean NOBR per Genotype (P = 23):
# GENOTYPE
# MS 1-8-1-4      5.11
# LT 11-3-3-12    5.10
# BB 8 -1 -5-2    5.00
# BB 3-9-7-5      4.89
# BB PRT          4.00
# LT PRT          3.78
# MS PRT          3.67
# Name: NOBR, dtype: float64
#
# 🔍 ANOVA for NOBR at Phosphorus = 80
#                  sum_sq    df         F    PR(>F)
# C(GENOTYPE)    8.324206   6.0  0.511128  0.797223
# Residual     143.859127  53.0       NaN       NaN
#
# 📌 Mean NOBR per Genotype (P = 80):
# GENOTYPE
# BB 3-9-7-5      5.00
# BB 8 -1 -5-2    5.00
# LT PRT          4.78
# MS PRT          4.71
# MS 1-8-1-4      4.67
# LT 11-3-3-12    4.12
# BB PRT          4.00
# Name: NOBR, dtype: float64
#
# 💧 ANOVA for NOBR at Moisture = 40
#                 sum_sq    df         F   PR(>F)
# C(GENOTYPE)  35.460256   6.0  4.145883  0.00343
# Residual     45.616667  32.0       NaN      NaN
#
# 📌 Mean NOBR per Genotype (M = 40):
# GENOTYPE
# BB 3-9-7-5      4.67
# BB 8 -1 -5-2    4.40
# LT 11-3-3-12    3.33
# MS 1-8-1-4      2.83
# LT PRT          2.33
# MS PRT          2.25
# BB PRT          2.17
# Name: NOBR, dtype: float64
#
# 💧 ANOVA for NOBR at Moisture = 60
#                 sum_sq    df         F    PR(>F)
# C(GENOTYPE)   2.904762   6.0  0.294686  0.935379
# Residual     57.500000  35.0       NaN       NaN
#
# 📌 Mean NOBR per Genotype (M = 60):
# GENOTYPE
# BB 8 -1 -5-2    5.17
# LT 11-3-3-12    5.17
# LT PRT          5.00
# MS 1-8-1-4      5.00
# BB 3-9-7-5      4.83
# BB PRT          4.50
# MS PRT          4.50
# Name: NOBR, dtype: float64
#
# 💧 ANOVA for NOBR at Moisture = 100
#                 sum_sq    df         F    PR(>F)
# C(GENOTYPE)  12.571429   6.0  2.167488  0.069939
# Residual     33.833333  35.0       NaN       NaN
#
# 📌 Mean NOBR per Genotype (M = 100):
# GENOTYPE
# MS 1-8-1-4      6.83
# LT 11-3-3-12    5.50
# LT PRT          5.50
# BB PRT          5.33
# BB 8 -1 -5-2    5.33
# BB 3-9-7-5      5.33
# MS PRT          5.00
# Name: NOBR, dtype: float64
#
# ===========================
# 📊 Trait: PLHT
# ===========================
#
# 🔍 ANOVA for PLHT at Phosphorus = 23
#                    sum_sq    df         F    PR(>F)
# C(GENOTYPE)   4510.169444   6.0  0.678996  0.667121
# Residual     61995.830556  56.0       NaN       NaN
#
# 📌 Mean PLHT per Genotype (P = 23):
# GENOTYPE
# MS PRT          87.22
# MS 1-8-1-4      85.33
# BB 8 -1 -5-2    82.38
# LT PRT          81.11
# BB PRT          80.22
# LT 11-3-3-12    72.40
# BB 3-9-7-5      60.78
# Name: PLHT, dtype: float64
#
# 🔍 ANOVA for PLHT at Phosphorus = 80
#                    sum_sq    df         F    PR(>F)
# C(GENOTYPE)   6554.108333   6.0  0.923494  0.485715
# Residual     62690.875000  53.0       NaN       NaN
#
# 📌 Mean PLHT per Genotype (P = 80):
# GENOTYPE
# MS PRT          108.00
# LT PRT           87.11
# BB 8 -1 -5-2     80.78
# MS 1-8-1-4       79.67
# LT 11-3-3-12     78.12
# BB 3-9-7-5       75.67
# BB PRT           71.22
# Name: PLHT, dtype: float64
#
# 💧 ANOVA for PLHT at Moisture = 40
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)  1508.930769   6.0  1.468287  0.220431
# Residual     5480.966667  32.0       NaN       NaN
#
# 📌 Mean PLHT per Genotype (M = 40):
# GENOTYPE
# BB 8 -1 -5-2    52.80
# BB PRT          48.17
# MS 1-8-1-4      47.50
# LT 11-3-3-12    42.50
# MS PRT          39.00
# BB 3-9-7-5      38.17
# LT PRT          33.50
# Name: PLHT, dtype: float64
#
# 💧 ANOVA for PLHT at Moisture = 60
#                    sum_sq    df         F    PR(>F)
# C(GENOTYPE)   4360.619048   6.0  1.154179  0.352655
# Residual     22039.000000  35.0       NaN       NaN
#
# 📌 Mean PLHT per Genotype (M = 60):
# GENOTYPE
# MS PRT          110.83
# LT PRT          104.67
# LT 11-3-3-12    100.83
# MS 1-8-1-4       95.83
# BB 8 -1 -5-2     89.50
# BB PRT           84.17
# BB 3-9-7-5       80.83
# Name: PLHT, dtype: float64
#
# 💧 ANOVA for PLHT at Moisture = 100
#                    sum_sq    df         F    PR(>F)
# C(GENOTYPE)   7188.142857   6.0  2.563819  0.036502
# Residual     16354.833333  35.0       NaN       NaN
#
# 📌 Mean PLHT per Genotype (M = 100):
# GENOTYPE
# MS PRT          120.00
# LT PRT          114.17
# MS 1-8-1-4      104.17
# BB 8 -1 -5-2     97.50
# BB PRT           94.83
# BB 3-9-7-5       85.67
# LT 11-3-3-12     81.50
# Name: PLHT, dtype: float64
#
# ===========================
# 📊 Trait: STMD
# ===========================
#
# 🔍 ANOVA for STMD at Phosphorus = 23
#                 sum_sq    df         F    PR(>F)
# C(GENOTYPE)   0.067508   6.0  0.059628  0.999086
# Residual     10.566778  56.0       NaN       NaN
#
# 📌 Mean STMD per Genotype (P = 23):
# GENOTYPE
# BB 3-9-7-5      2.56
# MS PRT          2.54
# BB PRT          2.51
# LT PRT          2.51
# LT 11-3-3-12    2.51
# MS 1-8-1-4      2.48
# BB 8 -1 -5-2    2.45
# Name: STMD, dtype: float64
#
# 🔍 ANOVA for STMD at Phosphorus = 80
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  0.588798   6.0  0.915725  0.491045
# Residual     5.679702  53.0       NaN       NaN
#
# 📌 Mean STMD per Genotype (P = 80):
# GENOTYPE
# BB PRT          2.67
# MS PRT          2.67
# BB 3-9-7-5      2.66
# LT 11-3-3-12    2.66
# BB 8 -1 -5-2    2.59
# LT PRT          2.57
# MS 1-8-1-4      2.38
# Name: STMD, dtype: float64
#
# 💧 ANOVA for STMD at Moisture = 40
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  1.341410   6.0  4.743108  0.001467
# Residual     1.508333  32.0       NaN       NaN
#
# 📌 Mean STMD per Genotype (M = 40):
# GENOTYPE
# BB 8 -1 -5-2    2.50
# BB 3-9-7-5      2.47
# LT PRT          2.42
# BB PRT          2.37
# LT 11-3-3-12    2.25
# MS PRT          2.05
# MS 1-8-1-4      1.98
# Name: STMD, dtype: float64
#
# 💧 ANOVA for STMD at Moisture = 60
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  0.248095   6.0  0.427119  0.855823
# Residual     3.388333  35.0       NaN       NaN
#
# 📌 Mean STMD per Genotype (M = 60):
# GENOTYPE
# LT PRT          2.73
# BB 3-9-7-5      2.60
# BB PRT          2.55
# LT 11-3-3-12    2.55
# BB 8 -1 -5-2    2.52
# MS 1-8-1-4      2.52
# MS PRT          2.48
# Name: STMD, dtype: float64
#
# 💧 ANOVA for STMD at Moisture = 100
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  1.632857   6.0  2.160681  0.070726
# Residual     4.408333  35.0       NaN       NaN
#
# 📌 Mean STMD per Genotype (M = 100):
# GENOTYPE
# MS PRT          3.08
# LT 11-3-3-12    2.93
# BB PRT          2.85
# MS 1-8-1-4      2.78
# BB 3-9-7-5      2.75
# BB 8 -1 -5-2    2.55
# LT PRT          2.47
# Name: STMD, dtype: float64
#
# ===========================
# 📊 Trait: RTBM
# ===========================
#
# 🔍 ANOVA for RTBM at Phosphorus = 23
#                  sum_sq    df         F        PR(>F)
# C(GENOTYPE)  785.849617   6.0  9.194888  5.271642e-07
# Residual     797.682012  56.0       NaN           NaN
#
# 📌 Mean RTBM per Genotype (P = 23):
# GENOTYPE
# MS PRT          12.58
# LT 11-3-3-12    12.55
# BB 3-9-7-5      11.94
# BB PRT          10.47
# LT PRT           8.73
# MS 1-8-1-4       3.87
# BB 8 -1 -5-2     3.82
# Name: RTBM, dtype: float64
#
# 🔍 ANOVA for RTBM at Phosphorus = 80
#                  sum_sq    df         F        PR(>F)
# C(GENOTYPE)  518.827655   6.0  9.039879  8.333045e-07
# Residual     506.973350  53.0       NaN           NaN
#
# 📌 Mean RTBM per Genotype (P = 80):
# GENOTYPE
# BB 8 -1 -5-2    13.36
# MS PRT          11.34
# LT PRT          11.28
# BB PRT           9.08
# BB 3-9-7-5       8.52
# LT 11-3-3-12     7.80
# MS 1-8-1-4       3.70
# Name: RTBM, dtype: float64
#
# 💧 ANOVA for RTBM at Moisture = 40
#                  sum_sq    df         F    PR(>F)
# C(GENOTYPE)  208.745067   6.0  5.516003  0.000515
# Residual     201.832187  32.0       NaN       NaN
#
# 📌 Mean RTBM per Genotype (M = 40):
# GENOTYPE
# BB 8 -1 -5-2    10.05
# BB 3-9-7-5       9.81
# MS PRT           8.62
# LT PRT           5.13
# BB PRT           5.12
# MS 1-8-1-4       5.03
# LT 11-3-3-12     4.34
# Name: RTBM, dtype: float64
#
# 💧 ANOVA for RTBM at Moisture = 60
#                  sum_sq    df         F    PR(>F)
# C(GENOTYPE)  432.484851   6.0  7.261476  0.000043
# Residual     347.426364  35.0       NaN       NaN
#
# 📌 Mean RTBM per Genotype (M = 60):
# GENOTYPE
# MS PRT          14.58
# LT 11-3-3-12    11.53
# BB PRT          10.93
# BB 3-9-7-5      10.91
# LT PRT          10.23
# BB 8 -1 -5-2     9.25
# MS 1-8-1-4       3.18
# Name: RTBM, dtype: float64
#
# 💧 ANOVA for RTBM at Moisture = 100
#                  sum_sq    df          F        PR(>F)
# C(GENOTYPE)  680.882904   6.0  11.320327  5.267802e-07
# Residual     350.857094  35.0        NaN           NaN
#
# 📌 Mean RTBM per Genotype (M = 100):
# GENOTYPE
# LT 11-3-3-12    15.44
# LT PRT          14.64
# BB PRT          13.28
# MS PRT          11.77
# BB 3-9-7-5       9.97
# BB 8 -1 -5-2     7.52
# MS 1-8-1-4       3.14
# Name: RTBM, dtype: float64
#
# ===========================
# 📊 Trait: RTD
# ===========================
#
# 🔍 ANOVA for RTD at Phosphorus = 23
#               sum_sq    df         F    PR(>F)
# C(GENOTYPE)  0.19773   6.0  3.427273  0.005946
# Residual     0.53847  56.0       NaN       NaN
#
# 📌 Mean RTD per Genotype (P = 23):
# GENOTYPE
# LT 11-3-3-12    0.48
# MS PRT          0.39
# BB 3-9-7-5      0.37
# MS 1-8-1-4      0.37
# BB PRT          0.34
# BB 8 -1 -5-2    0.33
# LT PRT          0.30
# Name: RTD, dtype: float64
#
# 🔍 ANOVA for RTD at Phosphorus = 80
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  0.114559   6.0  1.329371  0.260609
# Residual     0.761214  53.0       NaN       NaN
#
# 📌 Mean RTD per Genotype (P = 80):
# GENOTYPE
# MS PRT          0.41
# MS 1-8-1-4      0.40
# BB 8 -1 -5-2    0.40
# LT 11-3-3-12    0.37
# BB PRT          0.37
# BB 3-9-7-5      0.35
# LT PRT          0.28
# Name: RTD, dtype: float64
#
# 💧 ANOVA for RTD at Moisture = 40
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  0.203535   6.0  3.230638  0.013509
# Residual     0.336008  32.0       NaN       NaN
#
# 📌 Mean RTD per Genotype (M = 40):
# GENOTYPE
# LT 11-3-3-12    0.41
# BB 8 -1 -5-2    0.38
# BB 3-9-7-5      0.32
# BB PRT          0.32
# MS PRT          0.31
# MS 1-8-1-4      0.24
# LT PRT          0.19
# Name: RTD, dtype: float64
#
# 💧 ANOVA for RTD at Moisture = 60
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  0.087948   6.0  1.709523  0.147878
# Residual     0.300100  35.0       NaN       NaN
#
# 📌 Mean RTD per Genotype (M = 60):
# GENOTYPE
# MS 1-8-1-4      0.46
# LT 11-3-3-12    0.43
# BB PRT          0.42
# MS PRT          0.42
# BB 3-9-7-5      0.38
# BB 8 -1 -5-2    0.33
# LT PRT          0.33
# Name: RTD, dtype: float64
#
# 💧 ANOVA for RTD at Moisture = 100
#                sum_sq    df         F    PR(>F)
# C(GENOTYPE)  0.102062   6.0  1.618269  0.171325
# Residual     0.367900  35.0       NaN       NaN
#
# 📌 Mean RTD per Genotype (M = 100):
# GENOTYPE
# LT 11-3-3-12    0.46
# MS 1-8-1-4      0.46
# MS PRT          0.45
# BB 8 -1 -5-2    0.39
# BB 3-9-7-5      0.36
# BB PRT          0.34
# LT PRT          0.34
# Name: RTD, dtype: float64
#
# ===========================
# 📊 Trait: RTL
# ===========================
#
# 🔍 ANOVA for RTL at Phosphorus = 23
#                   sum_sq    df          F        PR(>F)
# C(GENOTYPE)  3608.146272   6.0  18.201057  1.376560e-11
# Residual     1850.223972  56.0        NaN           NaN
#
# 📌 Mean RTL per Genotype (P = 23):
# GENOTYPE
# BB PRT          43.43
# BB 8 -1 -5-2    40.39
# LT 11-3-3-12    38.28
# MS 1-8-1-4      34.71
# LT PRT          33.53
# BB 3-9-7-5      26.70
# MS PRT          19.80
# Name: RTL, dtype: float64
#
# 🔍 ANOVA for RTL at Phosphorus = 80
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)  2359.650558   6.0  7.071524  0.000014
# Residual     2947.537057  53.0       NaN       NaN
#
# 📌 Mean RTL per Genotype (P = 80):
# GENOTYPE
# BB PRT          43.33
# LT 11-3-3-12    40.66
# BB 8 -1 -5-2    34.18
# LT PRT          31.59
# MS 1-8-1-4      28.07
# BB 3-9-7-5      26.65
# MS PRT          26.27
# Name: RTL, dtype: float64
#
# 💧 ANOVA for RTL at Moisture = 40
#                  sum_sq    df          F        PR(>F)
# C(GENOTYPE)  2933.57216   6.0  20.354474  1.181078e-09
# Residual      768.66237  32.0        NaN           NaN
#
# 📌 Mean RTL per Genotype (M = 40):
# GENOTYPE
# LT 11-3-3-12    49.80
# BB PRT          42.17
# BB 3-9-7-5      32.18
# BB 8 -1 -5-2    31.49
# LT PRT          31.02
# MS 1-8-1-4      28.85
# MS PRT          20.05
# Name: RTL, dtype: float64
#
# 💧 ANOVA for RTL at Moisture = 60
#                   sum_sq    df          F        PR(>F)
# C(GENOTYPE)  2972.398842   6.0  15.460861  1.428189e-08
# Residual     1121.476564  35.0        NaN           NaN
#
# 📌 Mean RTL per Genotype (M = 60):
# GENOTYPE
# BB PRT          46.50
# BB 8 -1 -5-2    37.11
# MS 1-8-1-4      35.74
# LT PRT          31.42
# LT 11-3-3-12    30.18
# BB 3-9-7-5      21.60
# MS PRT          20.45
# Name: RTL, dtype: float64
#
# 💧 ANOVA for RTL at Moisture = 100
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)  1616.318459   6.0  7.801297  0.000023
# Residual     1208.584183  35.0       NaN       NaN
#
# 📌 Mean RTL per Genotype (M = 100):
# GENOTYPE
# BB 8 -1 -5-2    41.77
# BB PRT          41.47
# LT 11-3-3-12    38.04
# LT PRT          35.25
# MS 1-8-1-4      29.58
# MS PRT          26.53
# BB 3-9-7-5      26.25
# Name: RTL, dtype: float64
#
# ===========================
# 📊 Trait: GRNY
# ===========================
#
# 🔍 ANOVA for GRNY at Phosphorus = 23
#                   sum_sq    df          F        PR(>F)
# C(GENOTYPE)  6424.374667   6.0  14.810433  4.735437e-10
# Residual     4048.553533  56.0        NaN           NaN
#
# 📌 Mean GRNY per Genotype (P = 23):
# GENOTYPE
# MS 1-8-1-4      29.70
# MS PRT          27.60
# LT PRT           8.47
# BB 3-9-7-5       7.23
# BB 8 -1 -5-2     6.56
# LT 11-3-3-12     6.25
# BB PRT           4.02
# Name: GRNY, dtype: float64
#
# 🔍 ANOVA for GRNY at Phosphorus = 80
#                   sum_sq    df         F        PR(>F)
# C(GENOTYPE)  5966.210414   6.0  9.058697  8.119350e-07
# Residual     5817.782204  53.0       NaN           NaN
#
# 📌 Mean GRNY per Genotype (P = 80):
# GENOTYPE
# MS PRT          35.62
# MS 1-8-1-4      16.10
# LT 11-3-3-12    10.17
# LT PRT           9.42
# BB PRT           5.48
# BB 8 -1 -5-2     5.32
# BB 3-9-7-5       1.02
# Name: GRNY, dtype: float64
#
# 💧 ANOVA for GRNY at Moisture = 40
#                  sum_sq    df         F    PR(>F)
# C(GENOTYPE)  631.848186   6.0  4.812536  0.001332
# Residual     700.224722  32.0       NaN       NaN
#
# 📌 Mean GRNY per Genotype (M = 40):
# GENOTYPE
# MS PRT          15.71
# MS 1-8-1-4       9.50
# LT 11-3-3-12     8.84
# BB PRT           6.61
# BB 8 -1 -5-2     5.09
# LT PRT           2.78
# BB 3-9-7-5       2.07
# Name: GRNY, dtype: float64
#
# 💧 ANOVA for GRNY at Moisture = 60
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)  1771.086595   6.0  9.249609  0.000004
# Residual     1116.948633  35.0       NaN       NaN
#
# 📌 Mean GRNY per Genotype (M = 60):
# GENOTYPE
# MS PRT          24.69
# MS 1-8-1-4      11.41
# LT 11-3-3-12     8.41
# LT PRT           7.78
# BB 3-9-7-5       6.18
# BB PRT           5.55
# BB 8 -1 -5-2     3.98
# Name: GRNY, dtype: float64
#
# 💧 ANOVA for GRNY at Moisture = 100
#                    sum_sq    df           F        PR(>F)
# C(GENOTYPE)  14606.162233   6.0  466.001339  7.214067e-32
# Residual       182.837700  35.0         NaN           NaN
#
# 📌 Mean GRNY per Genotype (M = 100):
# GENOTYPE
# MS PRT          47.80
# MS 1-8-1-4      47.80
# LT PRT          16.28
# BB 8 -1 -5-2     8.49
# LT 11-3-3-12     6.73
# BB 3-9-7-5       4.12
# BB PRT           2.08
# Name: GRNY, dtype: float64
#
# ===========================
# 📊 Trait: PLDY
# ===========================
#
# 🔍 ANOVA for PLDY at Phosphorus = 23
#                   sum_sq    df          F        PR(>F)
# C(GENOTYPE)  3455.934020   6.0  25.185727  2.959053e-14
# Residual     1280.700954  56.0        NaN           NaN
#
# 📌 Mean PLDY per Genotype (P = 23):
# GENOTYPE
# MS 1-8-1-4      26.30
# MS PRT          13.18
# BB 3-9-7-5       7.23
# LT 11-3-3-12     6.46
# LT PRT           6.13
# BB 8 -1 -5-2     4.49
# BB PRT           3.23
# Name: PLDY, dtype: float64
#
# 🔍 ANOVA for PLDY at Phosphorus = 80
#                   sum_sq    df          F        PR(>F)
# C(GENOTYPE)  2485.419848   6.0  12.109761  1.603487e-08
# Residual     1812.962426  53.0        NaN           NaN
#
# 📌 Mean PLDY per Genotype (P = 80):
# GENOTYPE
# MS 1-8-1-4      20.77
# MS PRT          18.22
# LT PRT           9.25
# LT 11-3-3-12     7.35
# BB 3-9-7-5       4.33
# BB PRT           4.11
# BB 8 -1 -5-2     4.01
# Name: PLDY, dtype: float64
#
# 💧 ANOVA for PLDY at Moisture = 40
#                  sum_sq    df          F        PR(>F)
# C(GENOTYPE)  760.965308   6.0  14.341285  7.219488e-08
# Residual     282.992878  32.0        NaN           NaN
#
# 📌 Mean PLDY per Genotype (M = 40):
# GENOTYPE
# MS PRT          15.57
# MS 1-8-1-4      13.29
# BB 8 -1 -5-2     6.85
# LT 11-3-3-12     5.58
# BB 3-9-7-5       4.82
# BB PRT           4.28
# LT PRT           2.07
# Name: PLDY, dtype: float64
#
# 💧 ANOVA for PLDY at Moisture = 60
#                   sum_sq    df          F        PR(>F)
# C(GENOTYPE)  1272.841256   6.0  11.862296  3.145707e-07
# Residual      625.924954  35.0        NaN           NaN
#
# 📌 Mean PLDY per Genotype (M = 60):
# GENOTYPE
# MS 1-8-1-4      20.72
# MS PRT          13.42
# LT PRT          13.12
# LT 11-3-3-12     9.54
# BB 3-9-7-5       9.48
# BB PRT           4.20
# BB 8 -1 -5-2     3.38
# Name: PLDY, dtype: float64
#
# 💧 ANOVA for PLDY at Moisture = 100
#                   sum_sq    df           F        PR(>F)
# C(GENOTYPE)  5608.987467   6.0  231.223616  1.200443e-26
# Residual      141.504117  35.0         NaN           NaN
#
# 📌 Mean PLDY per Genotype (M = 100):
# GENOTYPE
# MS 1-8-1-4      36.60
# MS PRT          17.22
# LT PRT           7.88
# LT 11-3-3-12     5.45
# BB 3-9-7-5       3.03
# BB 8 -1 -5-2     2.91
# BB PRT           2.53
# Name: PLDY, dtype: float64
#
# ===========================
# 📊 Trait: PTBM
# ===========================
#
# 🔍 ANOVA for PTBM at Phosphorus = 23
#                    sum_sq    df         F    PR(>F)
# C(GENOTYPE)   9312.274107   6.0  7.995835  0.000003
# Residual     10869.978383  56.0       NaN       NaN
#
# 📌 Mean PTBM per Genotype (P = 23):
# GENOTYPE
# LT 11-3-3-12    79.41
# MS PRT          73.96
# MS 1-8-1-4      67.14
# BB 3-9-7-5      62.44
# BB PRT          60.45
# LT PRT          50.47
# BB 8 -1 -5-2    40.88
# Name: PTBM, dtype: float64
#
# 🔍 ANOVA for PTBM at Phosphorus = 80
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)   958.066420   6.0  0.886213  0.511608
# Residual     9549.528273  53.0       NaN       NaN
#
# 📌 Mean PTBM per Genotype (P = 80):
# GENOTYPE
# LT 11-3-3-12    58.10
# BB 3-9-7-5      56.40
# BB 8 -1 -5-2    53.67
# MS 1-8-1-4      50.50
# LT PRT          48.53
# BB PRT          48.27
# MS PRT          46.51
# Name: PTBM, dtype: float64
#
# 💧 ANOVA for PTBM at Moisture = 40
#                   sum_sq    df         F   PR(>F)
# C(GENOTYPE)  3553.193721   6.0  2.717538  0.03012
# Residual     6973.358783  32.0       NaN      NaN
#
# 📌 Mean PTBM per Genotype (M = 40):
# GENOTYPE
# LT 11-3-3-12    75.07
# BB 3-9-7-5      63.16
# BB PRT          61.56
# MS PRT          57.66
# MS 1-8-1-4      52.94
# LT PRT          48.55
# BB 8 -1 -5-2    44.75
# Name: PTBM, dtype: float64
#
# 💧 ANOVA for PTBM at Moisture = 60
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)  3540.712729   6.0  3.504889  0.008061
# Residual     5892.955581  35.0       NaN       NaN
#
# 📌 Mean PTBM per Genotype (M = 60):
# GENOTYPE
# MS 1-8-1-4      69.24
# MS PRT          59.01
# BB 3-9-7-5      54.43
# LT PRT          51.92
# BB PRT          51.30
# LT 11-3-3-12    44.88
# BB 8 -1 -5-2    38.21
# Name: PTBM, dtype: float64
#
# 💧 ANOVA for PTBM at Moisture = 100
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)  7251.059233   6.0  7.661156  0.000027
# Residual     5521.078750  35.0       NaN       NaN
#
# 📌 Mean PTBM per Genotype (M = 100):
# GENOTYPE
# LT 11-3-3-12    89.86
# MS PRT          67.75
# BB 3-9-7-5      60.66
# BB 8 -1 -5-2    59.52
# MS 1-8-1-4      54.30
# BB PRT          50.22
# LT PRT          48.04
# Name: PTBM, dtype: float64
#
# ===========================
# 📊 Trait: TBM
# ===========================
#
# 🔍 ANOVA for TBM at Phosphorus = 23
#                    sum_sq    df          F        PR(>F)
# C(GENOTYPE)  38789.469375   6.0  19.601184  3.596236e-12
# Residual     18470.060493  56.0        NaN           NaN
#
# 📌 Mean TBM per Genotype (P = 23):
# GENOTYPE
# MS PRT          127.31
# MS 1-8-1-4      127.01
# LT 11-3-3-12    104.67
# BB 3-9-7-5       88.83
# BB PRT           78.18
# LT PRT           73.80
# BB 8 -1 -5-2     55.75
# Name: TBM, dtype: float64
#
# 🔍 ANOVA for TBM at Phosphorus = 80
#                    sum_sq    df         F    PR(>F)
# C(GENOTYPE)  10596.873204   6.0  4.328863  0.001263
# Residual     21623.626456  53.0       NaN       NaN
#
# 📌 Mean TBM per Genotype (P = 80):
# GENOTYPE
# MS PRT          111.69
# MS 1-8-1-4       91.08
# LT 11-3-3-12     83.41
# LT PRT           78.49
# BB 8 -1 -5-2     76.36
# BB 3-9-7-5       70.27
# BB PRT           66.94
# Name: TBM, dtype: float64
#
# 💧 ANOVA for TBM at Moisture = 40
#                   sum_sq    df         F    PR(>F)
# C(GENOTYPE)  5991.506579   6.0  3.836355  0.005403
# Residual     8329.443563  32.0       NaN       NaN
#
# 📌 Mean TBM per Genotype (M = 40):
# GENOTYPE
# MS PRT          97.56
# LT 11-3-3-12    93.83
# MS 1-8-1-4      80.75
# BB 3-9-7-5      79.86
# BB PRT          77.57
# BB 8 -1 -5-2    66.74
# LT PRT          58.54
# Name: TBM, dtype: float64
#
# 💧 ANOVA for TBM at Moisture = 60
#                    sum_sq    df         F    PR(>F)
# C(GENOTYPE)  13692.952731   6.0  7.542821  0.000031
# Residual     10589.613171  35.0       NaN       NaN
#
# 📌 Mean TBM per Genotype (M = 60):
# GENOTYPE
# MS PRT          111.70
# MS 1-8-1-4      104.54
# LT PRT           83.05
# BB 3-9-7-5       81.00
# LT 11-3-3-12     74.35
# BB PRT           71.99
# BB 8 -1 -5-2     54.82
# Name: TBM, dtype: float64
#
# 💧 ANOVA for TBM at Moisture = 100
#                    sum_sq    df          F        PR(>F)
# C(GENOTYPE)  36931.199473   6.0  35.028947  2.165701e-13
# Residual      6150.113458  35.0        NaN           NaN
#
# 📌 Mean TBM per Genotype (M = 100):
# GENOTYPE
# MS PRT          144.53
# MS 1-8-1-4      141.83
# LT 11-3-3-12    117.48
# LT PRT           86.84
# BB 8 -1 -5-2     78.44
# BB 3-9-7-5       77.78
# BB PRT           68.11
# Name: TBM, dtype: float64

# %%
# ----------------------------
# @title Heatmaps of Genotype Performance Ranks Across Traits
# ----------------------------

# Traits to analyze
traits = ['GRNY', 'PLDY', 'TBM', 'RTBM', 'RTD', 'RTL']

# Calculate mean per genotype
mean_performance = df.groupby("GENOTYPE")[traits].mean()

# Rank the genotypes for each trait
rank_df = mean_performance.rank(ascending=False)

# Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(rank_df, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Rank'})
plt.title("Heatmap of Genotype Ranks Across Traits")
plt.xlabel("Trait")
plt.ylabel("Genotype")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_heatmap(df_long):
    """
    Plot a heatmap of genotype performance ranks across traits.
    Expects a long-format dataframe with columns: 'Genotype', 'Trait', 'Value'
    """
    # Calculate mean performance for each genotype-trait combination
    mean_perf = df_long.groupby(['Genotype', 'Trait'])['Value'].mean().unstack()

    # Rank genotypes within each trait (1=best)
    ranks = mean_perf.rank(ascending=False, method='min')

    # Plot heatmap
    plt.figure(figsize=(12, 8))
    sns.heatmap(ranks, annot=mean_perf.round(1), fmt='', cmap='YlGnBu_r',
                cbar_kws={'label': 'Performance Rank (1=best)'}, linewidths=0.5)
    plt.title('Genotype Performance Ranks Across Traits')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Traits to include
traits = ['GRNY', 'PLDY', 'TBM', 'RTBM', 'RTD', 'RTL']

# Melt wide dataframe to long format
df_long = df.melt(id_vars=['GENOTYPE'], value_vars=traits,
                  var_name='Trait', value_name='Value')

# Rename for compatibility with plot_heatmap
df_long = df_long.rename(columns={'GENOTYPE': 'Genotype'})

# Plot the heatmap
plot_heatmap(df_long)

# %%
# @title Interaction Plots: Genotype × Treatment Effects
from statsmodels.graphics.factorplots import interaction_plot

# Example for GRNY vs Phosphorus
plt.figure(figsize=(8, 5))
interaction_plot(df['GENOTYPE'], df['P'], df['GRNY'], colors=['red', 'blue'], markers=['D', '^'], ms=6)
plt.title("Genotype × Phosphorus Interaction for GRNY")
plt.ylabel("Grain Yield")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Example for GRNY vs Moisture
plt.figure(figsize=(8, 5))
interaction_plot(df['GENOTYPE'], df['M'], df['GRNY'], colors=['green', 'orange', 'purple'], markers=['o', 's', 'D'], ms=6)
plt.title("Genotype × Moisture Interaction for GRNY")
plt.ylabel("Grain Yield")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# @title Radar Charts Comparing Top-Performing Genotypes
import plotly.express as px
import plotly.graph_objects as go
import numpy as np

# Select top 3 genotypes by TBM
top_genotypes = df.groupby('GENOTYPE')['TBM'].mean().sort_values(ascending=False).head(3).index.tolist()

# Normalize data [0-1]
norm_df = df.groupby('GENOTYPE')[traits].mean()
norm_df = (norm_df - norm_df.min()) / (norm_df.max() - norm_df.min())
top_norm = norm_df.loc[top_genotypes]

# Radar chart
fig = go.Figure()

for geno in top_genotypes:
    fig.add_trace(go.Scatterpolar(
        r=top_norm.loc[geno].values,
        theta=traits,
        fill='toself',
        name=geno
    ))

fig.update_layout(
    polar=dict(radialaxis=dict(visible=True, range=[0, 1])),
    showlegend=True,
    title="Radar Chart of Top Genotypes"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c0e61637-b18a-4315-9d64-84a792f038ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0e61637-b18a-4315-9d64-84a792f038ff")) {                    Plotly.newPlot(                        "c0e61637-b18a-4315-9d64-84a792f038ff",                        [{"fill":"toself","name":"MS PRT ","r":[1.0,0.589568154166725,1.0,1.0,0.7867366412213742,0.0],"theta":["GRNY","PLDY","TBM","RTBM","RTD","RTL"],"type":"scatterpolar"},{"fill":"toself","name":"MS 1-8-1-4","r":[0.695824046860443,1.0,0.7875057941281678,0.0,0.6717557251908397,0.4222399468932454],"theta":["GRNY","PLDY","TBM","RTBM","RTD","RTL"],"type":"scatterpolar"},{"fill":"toself","name":"LT 11-3-3-12","r":[0.14325789200067945,0.16034793796411542,0.5307033762856348,0.806206710333246,1.0,0.8052417327021514],"theta":["GRNY","PLDY","TBM","RTBM","RTD","RTL"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"} ...

# %%
# @title Scatter Plots of Yield Components vs Root Traits
scatter_traits = [
    ('GRNY', 'RTBM'),
    ('TBM', 'RTD'),
    ('PLDY', 'RTL')
]

for y_trait, x_trait in scatter_traits:
    plt.figure(figsize=(7, 5))
    sns.scatterplot(data=df, x=x_trait, y=y_trait, hue='GENOTYPE', style='P', palette='tab10')
    plt.title(f"{y_trait} vs {x_trait} by Genotype")
    plt.xlabel(x_trait)
    plt.ylabel(y_trait)
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

# %%
# ----------------------------
# @title 5. Tukey HSD for Genotypes
# ----------------------------
for trait in available_traits:
    try:
        tukey = pairwise_tukeyhsd(endog=df[trait], groups=df['GENOTYPE'], alpha=0.05)
        print(f"\n📌 Tukey HSD for {trait} by Genotype:\n")
        print(tukey.summary())
    except Exception as e:
        print(f"\n⚠️ Error in Tukey HSD for {trait}: {str(e)}")
# Out:
# 📌 Tukey HSD for NOBR by Genotype:
#
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2   0.0556    1.0 -1.5548 1.6659  False
#   BB 3-9-7-5      BB PRT   -0.9444 0.5604 -2.5316 0.6428  False
#   BB 3-9-7-5 LT 11-3-3-12  -0.2778 0.9984  -1.865 1.3094  False
#   BB 3-9-7-5      LT PRT   -0.6667 0.8683 -2.2539 0.9205  False
#   BB 3-9-7-5   MS 1-8-1-4  -0.0556    1.0 -1.6428 1.5316  False
#   BB 3-9-7-5      MS PRT   -0.8194 0.7425 -2.4555 0.8166  False
# BB 8 -1 -5-2      BB PRT      -1.0 0.5086 -2.6104 0.6104  False
# BB 8 -1 -5-2 LT 11-3-3-12  -0.3333  0.996 -1.9437  1.277  False
# BB 8 -1 -5-2      LT PRT   -0.7222 0.8288 -2.3326 0.8881  False
# BB 8 -1 -5-2   MS 1-8-1-4  -0.1111    1.0 -1.7215 1.4993  False
# BB 8 -1 -5-2      MS PRT    -0.875 0.6933 -2.5335 0.7835  False
#      BB PRT  LT 11-3-3-12   0.6667 0.8683 -0.9205 2.2539  False
#      BB PRT       LT PRT    0.2778 0.9984 -1.3094  1.865  False
#      BB PRT    MS 1-8-1-4   0.8889 0.6303 -0.6983 2.4761  False
#      BB PRT       MS PRT     0.125    1.0  -1.511  1.761  False
# LT 11-3-3-12      LT PRT   -0.3889 0.9901 -1.9761 1.1983  False
# LT 11-3-3-12   MS 1-8-1-4   0.2222 0.9996  -1.365 1.8094  False
# LT 11-3-3-12      MS PRT   -0.5417 0.9545 -2.1777 1.0944  False
#      LT PRT    MS 1-8-1-4   0.6111 0.9091 -0.9761 2.1983  False
#      LT PRT       MS PRT   -0.1528    1.0 -1.7888 1.4833  False
#   MS 1-8-1-4      MS PRT   -0.7639 0.8002 -2.3999 0.8722  False
# ---------------------------------------------------------------
#
# 📌 Tukey HSD for PLHT by Genotype:
#
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#    group1       group2    meandiff p-adj   lower    upper  reject
# -----------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2  13.3072  0.899  -20.432 47.0464  False
#   BB 3-9-7-5      BB PRT       7.5 0.9936 -25.7538 40.7538  False
#   BB 3-9-7-5 LT 11-3-3-12   6.7222 0.9965 -26.5315  39.976  False
#   BB 3-9-7-5      LT PRT   15.8889 0.7824 -17.3649 49.1426  False
#   BB 3-9-7-5   MS 1-8-1-4  14.2778  0.856  -18.976 47.5315  False
#   BB 3-9-7-5      MS PRT   28.0903 0.1842  -6.1869 62.3675  False
# BB 8 -1 -5-2      BB PRT   -5.8072 0.9986 -39.5464  27.932  False
# BB 8 -1 -5-2 LT 11-3-3-12   -6.585 0.9971 -40.3242 27.1543  False
# BB 8 -1 -5-2      LT PRT    2.5817    1.0 -31.1575 36.3209  False
# BB 8 -1 -5-2   MS 1-8-1-4   0.9706    1.0 -32.7686 34.7098  False
# BB 8 -1 -5-2      MS PRT   14.7831 0.8613 -19.9653 49.5315  False
#      BB PRT  LT 11-3-3-12  -0.7778    1.0 -34.0315  32.476  False
#      BB PRT       LT PRT    8.3889 0.9884 -24.8649 41.6426  False
#      BB PRT    MS 1-8-1-4   6.7778 0.9963  -26.476 40.0315  False
#      BB PRT       MS PRT   20.5903 0.5491 -13.6869 54.8675  False
# LT 11-3-3-12      LT PRT    9.1667 0.9817 -24.0871 42.4204  False
# LT 11-3-3-12   MS 1-8-1-4   7.5556 0.9934 -25.6982 40.8093  False
# LT 11-3-3-12      MS PRT   21.3681 0.5038 -12.9091 55.6452  False
#      LT PRT    MS 1-8-1-4  -1.6111    1.0 -34.8649 31.6426  False
#      LT PRT       MS PRT   12.2014 0.9361 -22.0758 46.4786  False
#   MS 1-8-1-4      MS PRT   13.8125 0.8893 -20.4647 48.0897  False
# -----------------------------------------------------------------
#
# 📌 Tukey HSD for STMD by Genotype:
#
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===============================================================
#    group1       group2    meandiff p-adj   lower  upper  reject
# ---------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2   -0.082 0.9953 -0.4672 0.3031  False
#   BB 3-9-7-5      BB PRT   -0.0167    1.0 -0.3963 0.3629  False
#   BB 3-9-7-5 LT 11-3-3-12  -0.0278    1.0 -0.4074 0.3518  False
#   BB 3-9-7-5      LT PRT   -0.0667 0.9984 -0.4463 0.3129  False
#   BB 3-9-7-5   MS 1-8-1-4  -0.1778  0.798 -0.5574 0.2018  False
#   BB 3-9-7-5      MS PRT   -0.0056    1.0 -0.3968 0.3857  False
# BB 8 -1 -5-2      BB PRT    0.0654 0.9987 -0.3198 0.4505  False
# BB 8 -1 -5-2 LT 11-3-3-12   0.0542 0.9995 -0.3309 0.4394  False
# BB 8 -1 -5-2      LT PRT    0.0154    1.0 -0.3698 0.4005  False
# BB 8 -1 -5-2   MS 1-8-1-4  -0.0958 0.9893 -0.4809 0.2894  False
# BB 8 -1 -5-2      MS PRT    0.0765 0.9973 -0.3202 0.4731  False
#      BB PRT  LT 11-3-3-12  -0.0111    1.0 -0.3907 0.3685  False
#      BB PRT       LT PRT     -0.05 0.9997 -0.4296 0.3296  False
#      BB PRT    MS 1-8-1-4  -0.1611 0.8626 -0.5407 0.2185  False
#      BB PRT       MS PRT    0.0111    1.0 -0.3802 0.4024  False
# LT 11-3-3-12      LT PRT   -0.0389 0.9999 -0.4185 0.3407  False
# LT 11-3-3-12   MS 1-8-1-4    -0.15 0.8982 -0.5296 0.2296  False
# LT 11-3-3-12      MS PRT    0.0222    1.0 -0.3691 0.4135  False
#      LT PRT    MS 1-8-1-4  -0.1111 0.9751 -0.4907 0.2685  False
#      LT PRT       MS PRT    0.0611 0.9992 -0.3302 0.4524  False
#   MS 1-8-1-4      MS PRT    0.1722 0.8409 -0.2191 0.5635  False
# ---------------------------------------------------------------
#
# 📌 Tukey HSD for RTBM by Genotype:
#
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#    group1       group2    meandiff p-adj   lower    upper  reject
# -----------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2  -1.3546 0.9546   -5.448  2.7389  False
#   BB 3-9-7-5      BB PRT   -0.4524 0.9999   -4.487  3.5821  False
#   BB 3-9-7-5 LT 11-3-3-12     0.21    1.0  -3.8246  4.2445  False
#   BB 3-9-7-5      LT PRT   -0.2249    1.0  -4.2594  3.8097  False
#   BB 3-9-7-5   MS 1-8-1-4  -6.4431 0.0001 -10.4776 -2.4086   True
#   BB 3-9-7-5      MS PRT    1.8092 0.8481  -2.3495  5.9679  False
# BB 8 -1 -5-2      BB PRT    0.9021 0.9944  -3.1913  4.9955  False
# BB 8 -1 -5-2 LT 11-3-3-12   1.5645  0.912  -2.5289  5.6579  False
# BB 8 -1 -5-2      LT PRT    1.1297 0.9815  -2.9637  5.2231  False
# BB 8 -1 -5-2   MS 1-8-1-4  -5.0885 0.0054   -9.182 -0.9951   True
# BB 8 -1 -5-2      MS PRT    3.1638 0.2766  -1.0521  7.3796  False
#      BB PRT  LT 11-3-3-12   0.6624 0.9989  -3.3721  4.6969  False
#      BB PRT       LT PRT    0.2276    1.0  -3.8069  4.2621  False
#      BB PRT    MS 1-8-1-4  -5.9907 0.0004 -10.0252 -1.9561   True
#      BB PRT       MS PRT    2.2616 0.6621   -1.897  6.4203  False
# LT 11-3-3-12      LT PRT   -0.4348 0.9999  -4.4693  3.5997  False
# LT 11-3-3-12   MS 1-8-1-4  -6.6531 0.0001 -10.6876 -2.6185   True
# LT 11-3-3-12      MS PRT    1.5992 0.9096  -2.5594  5.7579  False
#      LT PRT    MS 1-8-1-4  -6.2182 0.0002 -10.2528 -2.1837   True
#      LT PRT       MS PRT    2.0341 0.7632  -2.1246  6.1928  False
#   MS 1-8-1-4      MS PRT    8.2523    0.0   4.0936  12.411   True
# -----------------------------------------------------------------
#
# 📌 Tukey HSD for RTD by Genotype:
#
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ================================================================
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2   0.0081    1.0 -0.1031  0.1193  False
#   BB 3-9-7-5      BB PRT    0.0006    1.0 -0.1091  0.1102  False
#   BB 3-9-7-5 LT 11-3-3-12   0.0739 0.4063 -0.0357  0.1835  False
#   BB 3-9-7-5      LT PRT   -0.0717 0.4446 -0.1813   0.038  False
#   BB 3-9-7-5   MS 1-8-1-4   0.0261 0.9915 -0.0835  0.1357  False
#   BB 3-9-7-5      MS PRT    0.0428  0.915 -0.0702  0.1558  False
# BB 8 -1 -5-2      BB PRT   -0.0075    1.0 -0.1188  0.1037  False
# BB 8 -1 -5-2 LT 11-3-3-12   0.0658 0.5676 -0.0454   0.177  False
# BB 8 -1 -5-2      LT PRT   -0.0798 0.3298  -0.191  0.0315  False
# BB 8 -1 -5-2   MS 1-8-1-4    0.018  0.999 -0.0932  0.1292  False
# BB 8 -1 -5-2      MS PRT    0.0347 0.9703 -0.0798  0.1493  False
#      BB PRT  LT 11-3-3-12   0.0733 0.4157 -0.0363   0.183  False
#      BB PRT       LT PRT   -0.0722 0.4349 -0.1818  0.0374  False
#      BB PRT    MS 1-8-1-4   0.0256 0.9924 -0.0841  0.1352  False
#      BB PRT       MS PRT    0.0423 0.9198 -0.0707  0.1553  False
# LT 11-3-3-12      LT PRT   -0.1456 0.0022 -0.2552 -0.0359   True
# LT 11-3-3-12   MS 1-8-1-4  -0.0478  0.847 -0.1574  0.0618  False
# LT 11-3-3-12      MS PRT    -0.031  0.982  -0.144   0.082  False
#      LT PRT    MS 1-8-1-4   0.0978 0.1137 -0.0118  0.2074  False
#      LT PRT       MS PRT    0.1145 0.0448  0.0015  0.2275   True
#   MS 1-8-1-4      MS PRT    0.0167 0.9994 -0.0963  0.1297  False
# ----------------------------------------------------------------
#
# 📌 Tukey HSD for RTL by Genotype:
#
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==================================================================
#    group1       group2    meandiff p-adj   lower    upper   reject
# ------------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2  10.4248 0.0003   3.5217  17.3279   True
#   BB 3-9-7-5      BB PRT   16.7025    0.0   9.8987  23.5063   True
#   BB 3-9-7-5 LT 11-3-3-12  12.6611    0.0   5.8573  19.4649   True
#   BB 3-9-7-5      LT PRT    5.8858 0.1368   -0.918  12.6896  False
#   BB 3-9-7-5   MS 1-8-1-4   4.7136 0.3721  -2.0902  11.5174  False
#   BB 3-9-7-5      MS PRT   -4.0482 0.5961 -11.0614    2.965  False
# BB 8 -1 -5-2      BB PRT    6.2777 0.1003  -0.6255  13.1808  False
# BB 8 -1 -5-2 LT 11-3-3-12   2.2363  0.959  -4.6668   9.1394  False
# BB 8 -1 -5-2      LT PRT    -4.539 0.4373 -11.4421   2.3641  False
# BB 8 -1 -5-2   MS 1-8-1-4  -5.7112 0.1753 -12.6144   1.1919  False
# BB 8 -1 -5-2      MS PRT   -14.473    0.0 -21.5826  -7.3634   True
#      BB PRT  LT 11-3-3-12  -4.0414 0.5626 -10.8452   2.7624  False
#      BB PRT       LT PRT  -10.8167 0.0001 -17.6205  -4.0129   True
#      BB PRT    MS 1-8-1-4 -11.9889    0.0 -18.7927  -5.1851   True
#      BB PRT       MS PRT  -20.7506    0.0 -27.7638 -13.7374   True
# LT 11-3-3-12      LT PRT   -6.7753 0.0517 -13.5791   0.0285  False
# LT 11-3-3-12   MS 1-8-1-4  -7.9475 0.0113 -14.7513  -1.1437   True
# LT 11-3-3-12      MS PRT  -16.7093    0.0 -23.7225  -9.6961   True
#      LT PRT    MS 1-8-1-4  -1.1722 0.9986   -7.976   5.6316  False
#      LT PRT       MS PRT    -9.934 0.0008 -16.9472  -2.9208   True
#   MS 1-8-1-4      MS PRT   -8.7617 0.0051 -15.7749  -1.7486   True
# ------------------------------------------------------------------
#
# 📌 Tukey HSD for GRNY by Genotype:
#
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#    group1       group2    meandiff p-adj   lower    upper  reject
# -----------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2   1.7756 0.9983  -8.2026 11.7538  False
#   BB 3-9-7-5      BB PRT    0.6244    1.0  -9.2102 10.4591  False
#   BB 3-9-7-5 LT 11-3-3-12   3.8656 0.9005  -5.9691 13.7002  False
#   BB 3-9-7-5      LT PRT    4.8206 0.7614  -5.0141 14.6552  False
#   BB 3-9-7-5   MS 1-8-1-4  18.7756    0.0   8.9409 28.6102   True
#   BB 3-9-7-5      MS PRT   26.9832    0.0  16.8459 37.1205   True
# BB 8 -1 -5-2      BB PRT   -1.1512 0.9999 -11.1294   8.827  False
# BB 8 -1 -5-2 LT 11-3-3-12   2.0899 0.9957  -7.8883 12.0681  False
# BB 8 -1 -5-2      LT PRT    3.0449 0.9694  -6.9333 13.0231  False
# BB 8 -1 -5-2   MS 1-8-1-4  16.9999    0.0   7.0217 26.9781   True
# BB 8 -1 -5-2      MS PRT   25.2076    0.0  14.9309 35.4842   True
#      BB PRT  LT 11-3-3-12   3.2411 0.9555  -6.5935 13.0757  False
#      BB PRT       LT PRT    4.1961 0.8596  -5.6385 14.0307  False
#      BB PRT    MS 1-8-1-4  18.1511    0.0   8.3165 27.9857   True
#      BB PRT       MS PRT   26.3587    0.0  16.2214 36.4961   True
# LT 11-3-3-12      LT PRT     0.955 0.9999  -8.8796 10.7896  False
# LT 11-3-3-12   MS 1-8-1-4    14.91 0.0003   5.0754 24.7446   True
# LT 11-3-3-12      MS PRT   23.1176    0.0  12.9803 33.2549   True
#      LT PRT    MS 1-8-1-4   13.955 0.0008   4.1204 23.7896   True
#      LT PRT       MS PRT   22.1626    0.0  12.0253 32.2999   True
#   MS 1-8-1-4      MS PRT    8.2076 0.1959  -1.9297 18.3449  False
# -----------------------------------------------------------------
#
# 📌 Tukey HSD for PLDY by Genotype:
#
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#    group1       group2    meandiff p-adj   lower    upper  reject
# -----------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2  -1.5413 0.9802  -7.0524  3.9698  False
#   BB 3-9-7-5      BB PRT   -2.1078 0.9059  -7.5396   3.324  False
#   BB 3-9-7-5 LT 11-3-3-12   1.0772 0.9969  -4.3546   6.509  False
#   BB 3-9-7-5      LT PRT    1.9144  0.939  -3.5174  7.3462  False
#   BB 3-9-7-5   MS 1-8-1-4  17.7553    0.0  12.3235 23.1871   True
#   BB 3-9-7-5      MS PRT    9.6028    0.0   4.0039 15.2018   True
# BB 8 -1 -5-2      BB PRT   -0.5665 0.9999  -6.0776  4.9446  False
# BB 8 -1 -5-2 LT 11-3-3-12   2.6185 0.7868  -2.8926  8.1296  False
# BB 8 -1 -5-2      LT PRT    3.4558 0.4966  -2.0554  8.9669  False
# BB 8 -1 -5-2   MS 1-8-1-4  19.2966    0.0  13.7855 24.8077   True
# BB 8 -1 -5-2      MS PRT   11.1442    0.0   5.4682 16.8201   True
#      BB PRT  LT 11-3-3-12    3.185 0.5778  -2.2468  8.6168  False
#      BB PRT       LT PRT    4.0222  0.292  -1.4096   9.454  False
#      BB PRT    MS 1-8-1-4  19.8631    0.0  14.4313 25.2949   True
#      BB PRT       MS PRT   11.7106    0.0   6.1117 17.3096   True
# LT 11-3-3-12      LT PRT    0.8372 0.9992  -4.5946   6.269  False
# LT 11-3-3-12   MS 1-8-1-4  16.6781    0.0  11.2463 22.1099   True
# LT 11-3-3-12      MS PRT    8.5256 0.0002   2.9267 14.1246   True
#      LT PRT    MS 1-8-1-4  15.8408    0.0   10.409 21.2726   True
#      LT PRT       MS PRT    7.6884 0.0014   2.0894 13.2874   True
#   MS 1-8-1-4      MS PRT   -8.1524 0.0005 -13.7514 -2.5535   True
# -----------------------------------------------------------------
#
# 📌 Tukey HSD for PTBM by Genotype:
#
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#    group1       group2    meandiff p-adj   lower    upper  reject
# -----------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2 -11.7655 0.2871 -27.5869  4.0559  False
#   BB 3-9-7-5      BB PRT    -5.055 0.9589 -20.6488 10.5388  False
#   BB 3-9-7-5 LT 11-3-3-12  10.5213  0.405  -5.0725 26.1151  False
#   BB 3-9-7-5      LT PRT   -9.9137 0.4795 -25.5075  5.6801  False
#   BB 3-9-7-5   MS 1-8-1-4  -0.5939    1.0 -16.1877 14.9999  False
#   BB 3-9-7-5      MS PRT     2.534 0.9991 -13.5397 18.6076  False
# BB 8 -1 -5-2      BB PRT    6.7105  0.863  -9.1109 22.5319  False
# BB 8 -1 -5-2 LT 11-3-3-12  22.2868 0.0009   6.4654 38.1082   True
# BB 8 -1 -5-2      LT PRT    1.8518 0.9998 -13.9696 17.6732  False
# BB 8 -1 -5-2   MS 1-8-1-4  11.1716 0.3487  -4.6498  26.993  False
# BB 8 -1 -5-2      MS PRT   14.2994 0.1256  -1.9952 30.5941  False
#      BB PRT  LT 11-3-3-12  15.5763 0.0505  -0.0175 31.1701  False
#      BB PRT       LT PRT   -4.8587 0.9661 -20.4525 10.7351  False
#      BB PRT    MS 1-8-1-4   4.4611 0.9778 -11.1327 20.0549  False
#      BB PRT       MS PRT     7.589 0.7918  -8.4847 23.6626  False
# LT 11-3-3-12      LT PRT   -20.435 0.0027 -36.0288 -4.8412   True
# LT 11-3-3-12   MS 1-8-1-4 -11.1152 0.3373  -26.709  4.4786  False
# LT 11-3-3-12      MS PRT   -7.9873 0.7496  -24.061  8.0863  False
#      LT PRT    MS 1-8-1-4   9.3198 0.5552   -6.274 24.9136  False
#      LT PRT       MS PRT   12.4477 0.2417   -3.626 28.5213  False
#   MS 1-8-1-4      MS PRT    3.1278 0.9972 -12.9458 19.2015  False
# -----------------------------------------------------------------
#
# 📌 Tukey HSD for TBM by Genotype:
#
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =================================================================
#    group1       group2    meandiff p-adj   lower    upper  reject
# -----------------------------------------------------------------
#   BB 3-9-7-5 BB 8 -1 -5-2 -12.8857 0.5613 -34.5558  8.7843  False
#   BB 3-9-7-5      BB PRT   -6.9908 0.9569  -28.349 14.3675  False
#   BB 3-9-7-5 LT 11-3-3-12   15.674 0.3025  -5.6842 37.0323  False
#   BB 3-9-7-5      LT PRT   -3.4036 0.9991 -24.7618 17.9547  False
#   BB 3-9-7-5   MS 1-8-1-4  29.4938 0.0012   8.1356 50.8521   True
#   BB 3-9-7-5      MS PRT   40.9292    0.0  18.9136 62.9448   True
# BB 8 -1 -5-2      BB PRT     5.895 0.9829 -15.7751  27.565  False
# BB 8 -1 -5-2 LT 11-3-3-12  28.5598 0.0025   6.8897 50.2298   True
# BB 8 -1 -5-2      LT PRT    9.4822 0.8446 -12.1879 31.1522  False
# BB 8 -1 -5-2   MS 1-8-1-4  42.3796    0.0  20.7095 64.0496   True
# BB 8 -1 -5-2      MS PRT   53.8149    0.0  31.4967 76.1331   True
#      BB PRT  LT 11-3-3-12  22.6648 0.0299   1.3066  44.023   True
#      BB PRT       LT PRT    3.5872 0.9988  -17.771 24.9455  False
#      BB PRT    MS 1-8-1-4  36.4846    0.0  15.1264 57.8429   True
#      BB PRT       MS PRT     47.92    0.0  25.9044 69.9355   True
# LT 11-3-3-12      LT PRT  -19.0776 0.1126 -40.4358  2.2806  False
# LT 11-3-3-12   MS 1-8-1-4  13.8198 0.4575  -7.5384  35.178  False
# LT 11-3-3-12      MS PRT   25.2552 0.0137   3.2396 47.2707   True
#      LT PRT    MS 1-8-1-4  32.8974 0.0002  11.5392 54.2556   True
#      LT PRT       MS PRT   44.3328    0.0  22.3172 66.3483   True
#   MS 1-8-1-4      MS PRT   11.4354 0.7086 -10.5802 33.4509  False
# -----------------------------------------------------------------

# %%
# ----------------------------
# @title 6. Visualization Section (Updated for available traits)
# ----------------------------
plt.figure(figsize=(18, 12))

# A. Plant Height by Genotype
plt.subplot(2, 3, 1)
sns.boxplot(data=df, x="GENOTYPE", y="PLHT", palette="Set2")
plt.title("Plant Height (PLHT) by Genotype")
plt.xticks(rotation=45)

# B. Grain Yield by Phosphorus & Moisture
plt.subplot(2, 3, 2)
sns.boxplot(data=df, x="P", y="GRNY", hue="M", palette="coolwarm")
plt.title("Grain Yield by Phosphorus & Moisture")

# C. Root Length by Genotype
plt.subplot(2, 3, 3)
sns.barplot(data=df, x="GENOTYPE", y="RTL", ci=95, palette="YlGnBu")
plt.title("Root Length (RTL) by Genotype")
plt.xticks(rotation=45)

# D. Grain Yield by Moisture
plt.subplot(2, 3, 4)
sns.boxplot(data=df, x="M", y="GRNY", palette="autumn")
plt.title("Grain Yield by Moisture Level")

# E. Plant Height by Moisture
plt.subplot(2, 3, 5)
sns.violinplot(data=df, x="M", y="PLHT", palette="Pastel1")
plt.title("Plant Height by Moisture Level")

# F. Heatmap of Trait Correlation
plt.subplot(2, 3, 6)
corr = df[available_traits].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Trait Correlation Heatmap")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-8f6d9a8bbbc5>:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-24-8f6d9a8bbbc5>:19: FutureWarning:
#
#
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#
# <ipython-input-24-8f6d9a8bbbc5>:19: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-24-8f6d9a8bbbc5>:25: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# <ipython-input-24-8f6d9a8bbbc5>:30: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# @title Kmeans Clustering, PCA, and Prediction
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# ----------------------------
# 8. PCA for Genotype Clustering
# ----------------------------
# First, let's define the traits we actually have in our dataset
available_traits = ['NOBR', 'PLHT', 'STMD', 'RTBM', 'RTD', 'RTL', 'GRNY', 'PLDY', 'PTBM', 'TBM']
available_traits = [trait for trait in available_traits if trait in df.columns]

# Use trait means per genotype (excluding GRNY if it's our target variable)
pca_traits = [trait for trait in available_traits if trait != 'GRNY']
trait_data = df.groupby('GENOTYPE')[pca_traits].mean()

# Standardize data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(trait_data)

# PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

# Plot PCA
pca_df = pd.DataFrame(pca_result, columns=["PC1", "PC2"])
pca_df["GENOTYPE"] = trait_data.index

plt.figure(figsize=(10, 8))
sns.scatterplot(data=pca_df, x="PC1", y="PC2", hue="GENOTYPE", palette="tab20", s=100)
plt.title("PCA: Genotype Clustering")
plt.axhline(0, ls="--", color="gray")
plt.axvline(0, ls="--", color="gray")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

# ----------------------------
# 9. KMeans Clustering of Genotypes
# ----------------------------
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# Plot Clusters
plt.figure(figsize=(10, 8))
sns.scatterplot(x=pca_result[:, 0], y=pca_result[:, 1], hue=clusters, palette="Set2", s=100)
for i, txt in enumerate(trait_data.index):
    plt.text(pca_result[i, 0] + 0.05, pca_result[i, 1], txt, fontsize=9)
plt.title("KMeans Clustering of Genotypes (3 Clusters)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.tight_layout()
plt.show()

# ----------------------------
# 10. Multiple Linear Regression: Predict GRNY
# ----------------------------
# Features: Use only available traits that aren't our target
if 'GRNY' in df.columns:
    # Exclude GRNY and any other non-numeric columns
    features = [trait for trait in available_traits if trait != 'GRNY' and trait not in ['GENOTYPE', 'P', 'M']]

    X = df[features]
    y = df['GRNY']

    # Train model
    reg = LinearRegression()
    reg.fit(X, y)
    y_pred = reg.predict(X)

    # Evaluation
    print("\n🔍 Linear Regression to Predict GRNY:")
    print("R² Score:", round(r2_score(y, y_pred), 3))
    print("RMSE:", round(np.sqrt(mean_squared_error(y, y_pred)), 3))


    # Coefficients
    coeff_df = pd.DataFrame({
        "Feature": X.columns,
        "Coefficient": reg.coef_
    }).sort_values("Coefficient", ascending=False)

    # Plot Coefficients
    plt.figure(figsize=(10, 5))
    sns.barplot(data=coeff_df, x="Coefficient", y="Feature", palette="coolwarm")
    plt.title("Feature Importance for Predicting Grain Yield (GRNY)")
    plt.axvline(0, color='gray', linestyle='--')
    plt.tight_layout()
    plt.show()
else:
    print("GRNY column not found in dataset - cannot perform regression analysis")
# Out:
# 🔍 Linear Regression to Predict GRNY:
# R² Score: 1.0
# RMSE: 0.0
# <ipython-input-12-8478259edc8a>:86: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=coeff_df, x="Coefficient", y="Feature", palette="coolwarm")
